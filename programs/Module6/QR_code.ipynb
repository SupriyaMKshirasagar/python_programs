# %%
import qrcode
data='QR Code using make() function'
img=qrcode.make(data)
img.save('MyQRCode1.png')

# %%
import qrcode
data="My Second QRCode"
qr=qrcode.QRCode(version=1,box_size=10,border=5)
qr.add_data(data)
qr.make(fit=True)
img=qr.make_image(fill_color='RED',back_color='BLACK')
img.save('MyQRCode2.png')

# %%
import gym
import numpy as np
from keras.models import Sequential
from keras.layers import Dense

# Create the CartPole environment
env = gym.make('CartPole-v1')

# Q-learning with function approximation using a neural network
def q_learning(env, episodes=1000, alpha=0.1, gamma=0.99, epsilon=0.1):
    n_actions = env.action_space.n
    n_states = env.observation_space.shape[0]
    model = build_q_network(n_states, n_actions)
    
    for episode in range(episodes):
        state = env.reset()
        state = np.reshape(state, [1, n_states])
        done = False

        while not done:
            if np.random.rand() < epsilon:
                action = env.action_space.sample()
            else:
                q_values = model.predict(state)
                action = np.argmax(q_values)

            next_state, reward, done, _ = env.step(action)
            next_state = np.reshape(next_state, [1, n_states])
            q_next = np.max(model.predict(next_state))
            
            target = reward + gamma * q_next
            target_vec = q_values
            target_vec[0, action] = target
            
            model.fit(state, target_vec, epochs=1, verbose=0)
            state = next_state

    return model

# Build the Q-network model
def build_q_network(input_dim, output_dim):
    model = Sequential()
    model.add(Dense(24, input_dim=input_dim, activation='relu'))
    model.add(Dense(24, activation='relu'))
    model.add(Dense(output_dim, activation='linear'))
    model.compile(loss='mse', optimizer='adam')
    return model

# Train Q-learning agent with neural network approximation
q_network = q_learning(env)

# Test the agent
state = env.reset()
done = False

while not done:
    state = np.reshape(state, [1, n_states])
    q_values = q_network.predict(state)
    action = np.argmax(q_values)
    next_state, _, done, _ = env.step(action)
    env.render()
    state = next_state

env.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9416\545903989.py in <module>
#      48
#      49 # Train Q-learning agent with neural network approximation
# ---> 50 q_network = q_learning(env)
#      51
#      52 # Test the agent
#
# ~\AppData\Local\Temp\ipykernel_9416\545903989.py in q_learning(env, episodes, alpha, gamma, epsilon)
#      15     for episode in range(episodes):
#      16         state = env.reset()
# ---> 17         state = np.reshape(state, [1, n_states])
#      18         done = False
#      19
#
# ~\AppData\Roaming\Python\Python39\site-packages\numpy\core\overrides.py in reshape(*args, **kwargs)
#
# ~\AppData\Roaming\Python\Python39\site-packages\numpy\core\fromnumeric.py in reshape(a, newshape, order)
#     296            [5, 6]])
#     297     """
# --> 298     return _wrapfunc(a, 'reshape', newshape, order=order)
# ...

# %% [markdown]
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9416\545903989.py in
#      48
#      49 # Train Q-learning agent with neural network approximation
# ---> 50 q_network = q_learning(env)
#      51
#      52 # Test the agent
#
# ~\AppData\Local\Temp\ipykernel_9416\545903989.py in q_learning(env, episodes, alpha, gamma, epsilon)
#      15     for episode in range(episodes):
#      16         state = env.reset()
# ---> 17         state = np.reshape(state, [1, n_states])
#      18         done = False
#      19
#
# ~\AppData\Roaming\Python\Python39\site-packages\numpy\core\overrides.py in reshape(*args, **kwargs)
#
# ~\AppData\Roaming\Python\Python39\site-packages\numpy\core\fromnumeric.py in reshape(a, newshape, order)
#     296            [5, 6]])
#     297     """
# --> 298     return _wrapfunc(a, 'reshape', newshape, order=order)
#     299
#     300
# ...
# ---> 43     result = getattr(asarray(obj), method)(*args, **kwds)
#             if wrap:
#      45         if not isinstance(result, mu.ndarray):
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.

# %%
import gym
import numpy as np
from keras.models import Sequential
from keras.layers import Dense

# Create the CartPole environment
env = gym.make('CartPole-v1')

## Q-learning with function approximation using a neural network
def q_learning(env, episodes=1000, alpha=0.1, gamma=0.99, epsilon=0.1):
    n_actions = env.action_space.n
    n_states = env.observation_space.shape[0]
    model = build_q_network(n_states, n_actions)

    for episode in range(episodes):
        state = env.reset()
        done = False

        while not done:
            if np.random.rand() < epsilon:
                action = env.action_space.sample()
            else:
                q_values = model.predict(np.array([state]))
                action = np.argmax(q_values)

            next_state, reward, done, _ = env.step(action)

            q_next = np.max(model.predict(np.array([next_state])))

            target = reward + gamma * q_next
            target_vec = q_values
            target_vec[0, action] = target

            model.fit(np.array([state]), target_vec, epochs=1, verbose=0)
            state = next_state

    return model

# ... Rest of the code ...


# Build the Q-network model
def build_q_network(input_dim, output_dim):
    model = Sequential()
    model.add(Dense(24, input_dim=input_dim, activation='relu'))
    model.add(Dense(24, activation='relu'))
    model.add(Dense(output_dim, activation='linear'))
    model.compile(loss='mse', optimizer='adam')
    return model

# Train Q-learning agent with neural network approximation
q_network = q_learning(env)

# Test the agent
state = env.reset()
done = False

while not done:
    q_values = q_network.predict(np.array([state]))
    action = np.argmax(q_values)
    next_state, _, done, _ = env.step(action)
    env.render()
    state = next_state

env.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9416\239630132.py in <module>
#      50
#      51 # Train Q-learning agent with neural network approximation
# ---> 52 q_network = q_learning(env)
#      53
#      54 # Test the agent
#
# ~\AppData\Local\Temp\ipykernel_9416\239630132.py in q_learning(env, episodes, alpha, gamma, epsilon)
#      21                 action = env.action_space.sample()
#      22             else:
# ---> 23                 q_values = model.predict(np.array([state]))
#      24                 action = np.argmax(q_values)
#      25
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (1, 2) + inhomogeneous part.
